# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score

# %%
#Step 1: Import data
file = "/Users/off-centreproductionsmacpro/Documents/GitHub/CYF_Python_Data_Project/data/raw/Raw-DataSet.csv"
df = pd.read_csv(file,  encoding = 'utf-8')

# %%
# identify missing values:
missing_data = df.isnull()
print(missing_data)
# Out:
#       _id  internal_id  contract_id  contract_title  contract_value  \
# 0   False        False        False           False           False
# 1   False        False        False           False           False
# 2   False        False        False           False           False
# 3   False        False        False           False           False
# 4   False        False        False           False           False
# 5   False        False        False           False           False
# 6   False        False        False           False           False
# 7   False        False        False           False           False
# 8   False        False        False           False           False
# 9   False        False        False           False           False
# 10  False        False        False           False           False
# 11  False        False        False           False           False
# 12  False        False        False           False           False
# ...

# %%
# Visual representation of missing data:

sns.heatmap(df.isnull(), cbar=False, cmap='viridis')
plt.show()

# %%
# Determine which rows (or indices) have missing values in the 'city,' 'locality,' and 'province' columns:

missing_city = df[df['city'].isnull()]
print(missing_city)
# Out:
#     _id  internal_id      contract_id  \
# 15   16        49468  97AF1A18820003A
# 16   17        49469  97AF1A188200049
# 22   23         1859     90BKC49D8714
# 23   24         1940     9365C49D8717
# 24   25         2372     922OC49D8411
# 25   26         2373     9131C49D8410
# 26   27         2460     9131C49D8429
# 27   28         2531     93A1C49D841E
# 28   29         4198     934OC49D841E
# 29   30         4216     94AUC49D8426
#
#                                    contract_title   contract_value  \
# 15                   تهیه و تامین تاسیسات مکانیکی   39,994,604,176
# 16  تهیه و تامین پنجره ها،درب های داخلی و آسانسور   20,000,000,000
# 22        خرید 17 قلم انواع قطعات یدکی ماشین آلات   32,433,978,200
# 23                          خرید 8 قلم قطعات یدکی   16,474,824,000
# 24                خرید 42 قلم  قطعات یدکی کمپرسور  174,144,413,750
# 25    خرید 146 قلم قطعات یدکی توربین گازی ورکسپور   49,673,390,000
# 26  خرید 68 قلم انواع قطعات یدکی کمپرسور های گازی  200,972,110,000
# ...

# %%
missing_locality = df[df['locality'].isnull()]
missing_province = df[df['province'].isnull()]
print(missing_city)
print(missing_locality)
print(missing_province)
